# %% [markdown]
# ## Notebook settings

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import logging
import tpvalidator.mcprod.workspace as workspace
import tpvalidator.utilities as utils
import tpvalidator.mcprod.analyzers.snn as snn

from rich import print
from tpvalidator.utilities import temporary_log_level, pandas_backend

# %% [markdown]
# # Load ADC mean and standard deviation from wafevorm histograms

# %%
with temporary_log_level(workspace.TriggerPrimitivesWorkspace._log, logging.INFO):
    ws = workspace.TriggerPrimitivesWorkspace("../../data/vd/pre_prod_1x8x14/anatree_vd_radiols_1x8x14_hist.root")

print(ws.info)
# Out:
# Key 'triggerAna/mcparticles' not found in file.
# Key 'triggerAna/simides' not found in file.
# {
#     'geo': {'detector': 'dunevd10kt_3view_30deg_v5_refactored_1x8x14ref'},
#     'mcthruth_blockid_map': [
#         [28, 'Rn222ChainFromPo218GenInUpperMesh1x8x14'],
#         [27, 'Rn220ChainFromPb212GenInUpperMesh1x8x14'],
#         [26, 'Kr85GenInLAr'],
#         [25, 'Rn222ChainFromBi210GenInUpperMesh1x8x14'],
#         [24, 'U238ChainGenInAnode'],
#         [23, 'K40GenInCathode'],
#         [22, 'K42From42ArGenInUpperMesh1x8x14'],
#         [21, 'Th232ChainGenInCathode'],
#         [20, 'CavernNGammasAtLAr1x8x14'],
#         [19, 'Rn222ChainRn222GenInLAr'],
#         [18, 'U238ChainGenInCathode'],
#         [17, 'K40GenInAnode'],
#         [16, 'Rn220ChainPb212GenInLAr'],
#         [15, 'foamGammasAtLAr1x8x14'],
#         [14, 'Rn222ChainFromPb214GenInUpperMesh1x8x14'],
#         [13, 'K42From42ArGenInLAr'],
#         [12, 'Rn222ChainGenInPDS'],
#         [11, 'Ar42GenInLAr'],
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
(ws.mctruths.query('generator_name == "CavernwallGammasAtLAr1x8x14"').kinetic_energy*1000).hist(ax=ax, bins=100)

ax.set_yscale('log')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
(ws.mctruths.query('generator_name == "CavernNGammasAtLAr1x8x14"').kinetic_energy*1000).hist(ax=ax, bins=100)

ax.set_yscale('log')
