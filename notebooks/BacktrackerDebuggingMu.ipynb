# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

figsize = (15,15)

# %% [markdown]
# ## TP Data loading (TPs and IDEs) + Waaveforms for event 47

# %%
import tpvalidator.basic as tvb
import tpvalidator.utilities as utils
import matplotlib.pyplot as plt
import matplotlib.patches as patches


# data_path = "../data/vd/ide/tpgtree_st_mu_minus_vd_tpg_2_old.root"
data_path = "../data/vd/ide/tpgtree_st_mu_minus_vd_tpg_9.root"
mu_vd = tvb.BasicTPData(data_path)

# FIXME: Waveform loading to be better integrated with the data object
waves = utils.load_sparse_waveform_data("../data/vd/trigger_digits_waves_mu_minus_vd_detsim_0.root")
ev_num = int(waves.event.unique()[0])
mu_vd.waveforms[ev_num] = waves
# Out:
# {
#     'geo': {'detector': 'dunevd10kt_3view_30deg_v5_refactored_1x8x6ref'},
#     'tpg': {
#         'threshold_tpg_plane0': 60,
#         'threshold_tpg_plane1': 60,
#         'threshold_tpg_plane2': 50,
#         'tool': 'TPAlgTPCSimpleThreshold'
#     },
#     'tptree': {'U_window_offset': 8, 'V_window_offset': 1, 'X_window_offset': -7}
# }
# [47]
# 1

# %% [markdown]
# ## Dataset visual inspection

# %%
fig = tvb.plot_3dev_points_of_origin(mu_vd)
fig.tight_layout()
# Out:
# /Users/ale/Development/dune/trigger-studies/tpvalidator/.venv/lib/python3.13/site-packages/mpl_toolkits/mplot3d/proj3d.py:148: RuntimeWarning: divide by zero encountered in dot
#   vecw = np.dot(M, vec.data)
# /Users/ale/Development/dune/trigger-studies/tpvalidator/.venv/lib/python3.13/site-packages/mpl_toolkits/mplot3d/proj3d.py:148: RuntimeWarning: overflow encountered in dot
#   vecw = np.dot(M, vec.data)
# /Users/ale/Development/dune/trigger-studies/tpvalidator/.venv/lib/python3.13/site-packages/mpl_toolkits/mplot3d/proj3d.py:148: RuntimeWarning: invalid value encountered in dot
#   vecw = np.dot(M, vec.data)

# %% [markdown]
# ## Event with poor backtracking efficiency of new algorithm

# %%
mu_vd.mc[(mu_vd.mc.detQ_U / mu_vd.mc.totQ_U) <  0.2]
# Out:
#                 event       Eng        Ekin  startX  startY  startZ        Px  \
# entry subentry
# 46    0            47  0.511042  405.383698     0.0   300.0   400.0 -0.483797
# 71    0            72  0.511042  405.383698     0.0   300.0   400.0 -0.484469
# 141   0           142  0.511042  405.383698     0.0   300.0   400.0 -0.399203
# 181   0           182  0.511042  405.383698     0.0   300.0   400.0 -0.464949
# 300   0           301  0.511042  405.383698     0.0   300.0   400.0 -0.466687
# 353   0           354  0.511042  405.383698     0.0   300.0   400.0 -0.395431
# 392   0           393  0.511042  405.383698     0.0   300.0   400.0 -0.489958
# 414   0           415  0.511042  405.383698     0.0   300.0   400.0  0.498537
# 467   0           468  0.511042  405.383698     0.0   300.0   400.0 -0.458983
# 514   0           515  0.511042  405.383698     0.0   300.0   400.0  0.495453
# 527   0           528  0.511042  405.383698     0.0   300.0   400.0  0.494495
# 719   0           720  0.511042  405.383698     0.0   300.0   400.0 -0.482784
# 737   0           738  0.511042  405.383698     0.0   300.0   400.0 -0.423005
# 753   0           754  0.511042  405.383698     0.0   300.0   400.0  0.469655
# 838   0           839  0.511042  405.383698     0.0   300.0   400.0 -0.426369
# 995   0           996  0.511042  405.383698     0.0   300.0   400.0 -0.495520
#
#                       Py        Pz    P      totQ_X      totQ_U      totQ_V  \
# entry subentry
# 46    0         0.039365  0.119961  0.5   9028237.0   9032566.0   9033291.0
# 71    0        -0.111517  0.053417  0.5   9167854.0   9173453.0   9173740.0
# 141   0        -0.161058  0.254356  0.5   9407453.0   9412445.0   9412468.0
# 181   0         0.058285 -0.174430  0.5   8940100.0   8945342.0   8944854.0
# 300   0         0.025754 -0.177595  0.5   9068300.0   9073290.0   9073437.0
# 353   0        -0.200995  0.230728  0.5   9102880.0   9107096.0   9107615.0
# 392   0        -0.015003  0.098569  0.5   9049151.0   9054671.0   9054233.0
# 414   0        -0.006101 -0.037729  0.5  10274057.0  10276292.0  10277322.0
# 467   0         0.063289 -0.187960  0.5   9183084.0   9188800.0   9188516.0
# 514   0        -0.055707  0.037723  0.5  10115474.0  10118015.0  10117895.0
# 527   0         0.059283 -0.044271  0.5  10076744.0  10078874.0  10079609.0
# 719   0        -0.060441 -0.115178  0.5   8986551.0   8990917.0   8990397.0
# 737   0        -0.147672  0.221946  0.5   9281270.0   9286088.0   9286358.0
# 753   0         0.037821 -0.167313  0.5  10119395.0  10122836.0  10122200.0
# 838   0         0.111079 -0.236370  0.5   9179957.0   9185617.0   9185053.0
# 995   0         0.034563  0.057144  0.5   8973134.0   8978065.0   8978222.0
#
#                    detQ_X       detQ_U       detQ_V
# entry subentry
# 46    0         8633923.0  1446880.125  2714664.000
# 71    0         8402681.0  1636328.500  2325824.500
# 141   0         9131337.0  1869103.375  7288547.000
# 181   0         8606288.0  1333281.875  4383451.000
# 300   0         8704687.0  1608952.125  2077096.125
# 353   0         8895992.0  1524707.375  6602596.000
# 392   0         8626624.0  1414981.500  1362653.875
# 414   0         9470425.0  2043560.375  1954893.375
# 467   0         8884577.0  1518257.000  4883016.000
# 514   0         9546396.0  2014596.750  2260730.250
# 527   0         9688537.0  1881828.375  2563152.250
# 719   0         8347479.5  1154500.125  1342783.750
# 737   0         8809389.0  1647192.375  4391753.000
# 753   0         9914346.0  1911354.000  5967560.500
# 838   0         8862031.0  1568199.750  5747536.500
# 995   0         8092892.5  1683198.500  1783322.750

# %%
mu_vd.angles[mu_vd.angles.event.isin(list(mu_vd.mc[(mu_vd.mc.detQ_U / mu_vd.mc.totQ_U) <  0.2].event))]
# Out:
#                 event     theta_y    theta_yU    theta_yV    theta_xz  \
# entry subentry
# 46    0            47   85.484428   75.691444   99.695610   76.073944
# 71    0            72  102.887321   91.088440  101.773239   83.708008
# 141   0           142  108.790901   73.769615  126.985703   57.496346
# 181   0           182   83.305794  104.113060   68.874855  110.564034
# 300   0           301   87.047447  106.370628   70.527252  110.834061
# 353   0           354  113.702652   78.542686  126.914894   59.737041
# 392   0           393   91.719521   81.041229  100.703735   78.625107
# 414   0           415   90.699081   94.097206   86.603371   94.327835
# 467   0           468   82.728104  105.204689   67.117279  112.269844
# 514   0           515   96.396828   89.448196   96.952400   85.646019
# 527   0           528   83.190666   90.996796   82.185745   95.115891
# 719   0           720   96.942970  105.066238   82.006882  103.418289
# 737   0           738  107.178192   76.305237  122.147034   62.314495
# 753   0           754   85.661858  104.594315   70.875877  109.608253
# 838   0           839   77.164223  107.357109   58.635292  119.003059
# 995   0           996   86.036186   82.325829   93.693153   83.421631
#
#                  theta_xzU   theta_xzV  theta_drift  theta_beam  theta_coll  \
# entry subentry
# 46    0          86.936836   78.996460   165.373932   76.118042   85.484428
# 71    0          75.722679   98.206367   165.682098   83.867119  102.887321
# 141   0          56.258022   91.765068   142.978195   59.421879  108.790901
# 181   0         106.496284   94.517906   158.418762  110.417564   83.305794
# 300   0         103.390839   98.108932   158.966965  110.805122   87.047447
# 353   0          53.798161   98.444046   142.266083   62.518871  113.702652
# 392   0          82.756035   85.763817   168.497574   78.630302   91.719521
# 414   0          91.560463   92.773064     4.383829   94.327507   90.699081
# 467   0         107.961319   94.877892   156.630493  112.081238   82.728104
# 514   0          82.286682   93.393890     7.732891   85.673172   96.396828
# 527   0          98.451591   86.620026     8.509762   95.079712   83.190666
# 719   0          90.622559  102.827805   164.921188  103.318077   96.942970
# 737   0          60.547596   92.289902   147.780228   63.647537  107.178192
# 753   0         103.920998   96.185699    20.063955  109.549782   85.661858
# 838   0         116.693626   92.952156   148.510757  118.212318   77.164223
# 995   0          90.157318   83.266418   172.324219   83.437439   86.036186
#
#                    theta_u     theta_v    phi_coll   phi_ind_u   phi_ind_v
# entry subentry
# 46    0          80.304382   75.691437  166.073944  168.996445  176.936829
# 71    0          78.226761   91.088432  173.707993  171.793625  165.722672
# 141   0          53.014290   73.769608  147.496338  178.234909  146.258011
# 181   0         111.125145  104.113052  159.435944  175.482086  163.503708
# 300   0         109.472748  106.370621  159.165924  171.891052  166.609146
# 353   0          53.085098   78.542686  149.737045  171.555939  143.798157
# 392   0          79.296265   81.041222  168.625107  175.763809  172.756027
# 414   0          93.396629   94.097206    4.327841    2.773067    1.560471
# 467   0         112.882713  105.204681  157.730148  175.122086  162.038681
# 514   0          83.047600   89.448196    4.353976    3.393894    7.713308
# 527   0          97.814255   90.996796    5.115895    3.379973    8.451597
# 719   0          97.993118  105.066231  166.581696  167.172180  179.377426
# 737   0          57.852962   76.305237  152.314499  177.710098  150.547592
# 753   0         109.124115  104.594307   19.608255    6.185705   13.921002
# 838   0         121.364693  107.357109  150.996918  177.047821  153.306366
# 995   0          86.306839   82.325821  173.421616  173.266418  179.842667

# %% [markdown]
# ## Event 208, low backtracker efficiency with old algorithm

# %%
from tpvalidator.backtracker import BackTrackerPlotter

ev_num = 208

fig, ax = plt.subplots(subplot_kw={'projection': '3d'}, figsize=(5,5))
basic.draw_tps_point_of_origin(ax, mu_vd, ev_num, is_signal=True)

tp_idx = [4,0,4]


btp = BackTrackerPlotter(mu_vd, ev_num)
# fig = btp.plot_tps_vs_ides([100,100])
fig = btp.plot_tps_vs_ides_one_per_plane(tp_idx, figsize=(10,4))

fig.tight_layout()
# Out:
# Warning: no waveform data found in ../data/vd/ide/tpgtree_st_mu_minus_vd_tpg_9.root for event 208
# No waveforms found for event '208'
# No waveforms found for event '208'
# No waveforms found for event '208'
#                    event  n_TPs  TP_channel  TP_startT  TP_peakT  TP_peakADC  \
# [entry, subentry]
# 0                  208.0  615.0      4570.0     6357.0    6358.0        74.0
# 1                  208.0  615.0      4690.0     6594.0    6598.0       110.0
# 2                  208.0  615.0      5138.0     6370.0    6373.0       105.0
#
#                    TP_SADC  TP_TOT  TP_plane  TP_TPC  TP_trueX  TP_trueY  \
# [entry, subentry]
# 0                    206.0     3.0       0.0     5.0    -185.0     316.0
# 1                    774.0     8.0       1.0     5.0    -204.0     320.0
# 2                    599.0     7.0       2.0     5.0    -185.0     316.0
#
#                    TP_trueZ  TP_signal
# [entry, subentry]
# 0                     126.0        1.0
# 1                     103.0        1.0
# 2                     126.0        1.0
# /Users/ale/Development/dune/trigger-studies/tpvalidator/.venv/lib/python3.13/site-packages/mpl_toolkits/mplot3d/proj3d.py:148: RuntimeWarning: divide by zero encountered in dot
#   vecw = np.dot(M, vec.data)
# /Users/ale/Development/dune/trigger-studies/tpvalidator/.venv/lib/python3.13/site-packages/mpl_toolkits/mplot3d/proj3d.py:148: RuntimeWarning: overflow encountered in dot
#   vecw = np.dot(M, vec.data)
# /Users/ale/Development/dune/trigger-studies/tpvalidator/.venv/lib/python3.13/site-packages/mpl_toolkits/mplot3d/proj3d.py:148: RuntimeWarning: invalid value encountered in dot
#   vecw = np.dot(M, vec.data)

# %% [markdown]
# ## Event 47, low efficiency ( < 0.2) on U plane with new algorithm

# %%
ev_num = 47

# fig, ax = plt.subplots(subplot_kw={'projection': '3d'}, figsize=(8,8))
# basic.draw_tps_point_of_origin(ax, mu, ev_num, is_signal=True)

tp_idx = [40,46,66]

# df_sel_tps = plot_3_tps_and_ides_from_event(mu_vd, ev_num, tp_idx)
# print(df_sel_tps.to_markdown())
# print(mu_vd.mc[mu_vd.mc.event == ev_num].to_markdown())

btp = BackTrackerPlotter(mu_vd, ev_num)
# fig = btp.plot_tps_vs_ides([100,100])
fig = btp.plot_tps_vs_ides_one_per_plane([20,0,4], figsize=(14,6))

fig.tight_layout()

print(btp.selected_tps.to_markdown())
# Out:
# |   entry |   subentry |   event |   n_TPs |   TP_channel |   TP_startT |   TP_peakT |   TP_peakADC |   TP_SADC |   TP_TOT |   TP_plane |   TP_TPC |   TP_trueX |   TP_trueY |   TP_trueZ |
# |--------:|-----------:|--------:|--------:|-------------:|------------:|-----------:|-------------:|----------:|---------:|-----------:|---------:|-----------:|-----------:|-----------:|
# |       0 |         47 |     224 |   18364 |         4619 |        4620 |         81 |          222 |         3 |        0 |         21 |      -46 |        298 |        410 |          1 |
# |       1 |         47 |     224 |   18536 |         4049 |        4053 |        222 |         1811 |        11 |        1 |         21 |        0 |        300 |        400 |          1 |
# |       2 |         47 |     224 |   18916 |         4114 |        4136 |        324 |         9912 |        50 |        2 |         21 |       -6 |        300 |        401 |          1 |

# %% [markdown]
# ```ide_chans = set(c for c in mu_vd.ides[mu_vd.ides.event == ev_num].channel.unique())
# raw_chans  = set( int(c) for c in chans)
#
# len(ide_chans)
# len(raw_chans)
# len(raw_chans.intersection(ide_chans))
# ```

# %%
ev_num = 47
from tpvalidator.backtracker import BackTrackerPlotter
btp = BackTrackerPlotter(mu_vd, ev_num)
# fig = btp.plot_tps_vs_ides([100,100])
fig = btp.plot_tps_vs_ides_by_plane(0, [0,1,21,22,23,24], figsize=(15,8))
fig.tight_layout()

fig = btp.plot_tps_vs_ides_by_plane(1, [0,1,21,22,23,24], figsize=(15,8))
fig.tight_layout()

fig = btp.plot_tps_vs_ides_by_plane(2, [0,1,21,22,23,24], figsize=(15,8))
fig.tight_layout()
# Out:
#                    event  n_TPs  TP_channel  TP_startT  TP_peakT  TP_peakADC  \
# [entry, subentry]
# 0                   47.0  224.0     18337.0     6306.0    6310.0       208.0
# 1                   47.0  224.0     18338.0     6307.0    6310.0       231.0
# 2                   47.0  224.0     18364.0     4663.0    4664.0        85.0
# 3                   47.0  224.0     18364.0     4681.0    4683.0        87.0
# 4                   47.0  224.0     18364.0     4708.0    4711.0       181.0
# 5                   47.0  224.0     18364.0     4799.0    4802.0       126.0
#
#                    TP_SADC  TP_TOT  TP_plane  TP_TPC  TP_trueX  TP_trueY  \
# [entry, subentry]
# 0                   1204.0     8.0       0.0    21.0    -181.0     255.0
# 1                   1301.0     8.0       0.0    21.0    -181.0     255.0
# 2                    380.0     5.0       0.0    21.0     -50.0     298.0
# 3                    294.0     4.0       0.0    21.0     -51.0     298.0
# 4                    874.0     6.0       0.0    21.0     -53.0     298.0
# 5                    675.0     7.0       0.0    21.0     -61.0     297.0
#
#                    TP_trueZ  TP_signal
# [entry, subentry]
# 0                     444.0        1.0
# 1                     444.0        1.0
# 2                     411.0        1.0
# 3                     411.0        1.0
# 4                     412.0        1.0
# 5                     413.0        1.0
#                    event  n_TPs  TP_channel  TP_startT  TP_peakT  TP_peakADC  \
# [entry, subentry]
# 0                   47.0  224.0     18536.0     4049.0    4053.0       222.0
# 1                   47.0  224.0     18536.0     4069.0    4070.0        77.0
# 2                   47.0  224.0     18545.0     4553.0    4559.0       175.0
# 3                   47.0  224.0     18545.0     4608.0    4608.0        64.0
# 4                   47.0  224.0     18545.0     4611.0    4611.0        68.0
# 5                   47.0  224.0     18545.0     4626.0    4627.0        83.0
#
#                    TP_SADC  TP_TOT  TP_plane  TP_TPC  TP_trueX  TP_trueY  \
# [entry, subentry]
# 0                   1811.0    11.0       1.0    21.0       0.0     300.0
# 1                    214.0     3.0       1.0    21.0      -1.0     300.0
# 2                   1599.0    12.0       1.0    21.0     -41.0     298.0
# 3                     64.0     1.0       1.0    21.0     -44.0     298.0
# 4                     68.0     1.0       1.0    21.0     -45.0     298.0
# 5                    309.0     4.0       1.0    21.0     -46.0     298.0
#
#                    TP_trueZ  TP_signal
# [entry, subentry]
# 0                     400.0        1.0
# 1                     400.0        1.0
# 2                     410.0        1.0
# 3                     410.0        1.0
# 4                     410.0        1.0
# 5                     410.0        1.0
#                    event  n_TPs  TP_channel  TP_startT  TP_peakT  TP_peakADC  \
# [entry, subentry]
# 0                   47.0  224.0     18913.0     4055.0    4062.0       344.0
# 1                   47.0  224.0     18914.0     4061.0    4061.0        58.0
# 2                   47.0  224.0     18931.0     4502.0    4531.0       318.0
# 3                   47.0  224.0     18932.0     4534.0    4566.0       679.0
# 4                   47.0  224.0     18933.0     4562.0    4568.0       470.0
# 5                   47.0  224.0     18934.0     4602.0    4636.0       404.0
#
#                    TP_SADC  TP_TOT  TP_plane  TP_TPC  TP_trueX  TP_trueY  \
# [entry, subentry]
# 0                   7162.0    30.0       2.0    21.0       0.0     300.0
# 1                    114.0     2.0       2.0    21.0       0.0     300.0
# 2                  12319.0    63.0       2.0    21.0     -38.0     298.0
# 3                  14408.0    61.0       2.0    21.0     -40.0     298.0
# 4                  16048.0    66.0       2.0    21.0     -42.0     298.0
# 5                  12434.0    55.0       2.0    21.0     -46.0     298.0
#
#                    TP_trueZ  TP_signal
# [entry, subentry]
# 0                     400.0        1.0
# 1                     400.0        1.0
# 2                     409.0        1.0
# 3                     409.0        1.0
# 4                     410.0        1.0
# 5                     410.0        1.0

# %%
x = mu_vd.ides[mu_vd.ides.event == 47].copy()
y = x[['time', 'nElectrons', 'channel']]
df_pivoted = y.pivot(index='time', columns='channel', values='nElectrons')

df_pivoted.plot(figsize=(10,8))
plt.tight_layout()
# Out:
# /var/folders/dw/sj94s2457kl2gkb829ty4_cc0000gn/T/ipykernel_88089/3109909385.py:6: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib
cmap = matplotlib.colormaps['tab10']

display(cmap)
cmap = matplotlib.colormaps['tab20']
display(cmap)

# %%
data_path = "../data/vd_test/tpgtree_st_mu_minus_vd_tpg_0.root"
mu_minus_vd_data = tvb.BasicTPData(data_path)
# Out:
# {
#     'geo': {'detector': 'dunevd10kt_3view_30deg_v5_refactored_1x8x6ref'},
#     'tpg': {
#         'threshold_tpg_plane0': 60,
#         'threshold_tpg_plane1': 60,
#         'threshold_tpg_plane2': 50,
#         'tool': 'TPAlgTPCSimpleThreshold'
#     },
#     'tptree': {'U_window_offset': 8, 'V_window_offset': 1, 'X_window_offset': -7}
# }

# %%
print(mu_minus_vd_data.info['tpg'])
# Out:
# {'threshold_tpg_plane0': 60, 'threshold_tpg_plane1': 60, 'threshold_tpg_plane2': 50, 'tool': 'TPAlgTPCSimpleThreshold'}
